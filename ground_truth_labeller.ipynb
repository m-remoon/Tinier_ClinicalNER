# %%
import os
import json
import openai
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.schema import HumanMessage  

# Initialize LangChain with OpenAI LLM
llm = ChatOpenAI(model_name="gpt-4", openai_api_key="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")

# Define prompt template for labeling
prompt_template = """
You are an expert in medical instruction parsing. Each instruction has words or tokens that belong to one of the following categories: {label_list}.

Below is an example of how to correctly label tokens:

Example Instruction: "1. Duloxetine 60 mg Capsule Sig: One (1) Capsule PO DAILY for depression."

Tokenized Tokens and Corresponding Labels:
1.              : O
Duloxetine      : B-DRUG
60              : B-STRENGTH
mg              : I-STRENGTH
Capsule         : B-FORM
Sig:            : O
One             : B-DOSAGE
(1)             : B-DOSAGE
Capsule         : B-FORM
PO              : B-ROUTE
DAILY           : B-FREQUENCY
for             : O
depression.     : B-REASON

Now, based on the provided categories, please label the following instruction **without adding any extra explanation or commentary**. Only output the tokens and their corresponding labels in the format: "<token> -> <label>".

Instruction: "{instruction}"

For each word in the instruction, assign the correct label from the categories. Use the format: "<token> -> <label>".

Please do not provide any explanation, context, or additional information—strictly follow the format requested.
Instruction:
"""

# Define the label list
label_list = ["O", "B-DRUG", "I-DRUG", "B-STRENGTH", "I-STRENGTH",
              "B-FORM", "I-FORM", "B-DOSAGE", "I-DOSAGE",
              "B-FREQUENCY", "I-FREQUENCY", "B-ROUTE", "I-ROUTE",
              "B-REASON", "I-REASON"]

# Simple space-based tokenizer
def simple_tokenizer(text):
    """Simple space-based tokenizer."""
    return text.split()

# Function to create the prompt for LangChain
def create_prompt(instruction):
    return prompt_template.format(instruction=instruction, label_list=", ".join(label_list))

# Adjusted function to use `HumanMessage` and `invoke`
def generate_labels_for_instruction(instruction):
    # Create a prompt for the LLM
    prompt = create_prompt(instruction)
    
    # Use LangChain's updated class with the `invoke` method
    response = llm.invoke([HumanMessage(content=prompt)])
    
    # Process the LLM response to extract tokens and labels
    tokens = []
    labels = []
    
    # Example processing of response: "<token> -> <label>"
    for line in response.content.split('\n'):  # Use `response.content` for the text
        if '->' in line:
            parts = line.split('->')

            # Check if the split result is exactly two parts
            if len(parts) == 2:
                token, label = parts
                tokens.append(token.strip())
                labels.append(label.strip())
            else:
                # If there's an unexpected format, assign the label "O" to the token
                print(f"Warning: Unexpected format in line: {line}")
        else:
            # If no delimiter found, treat the entire line as a single token with label "O"
            tokens.append(line.strip())
            labels.append("O")
            print(f"Warning: Unexpected format in line: {line} - Defaulting label to 'O'.")
    
    return tokens, labels

# Function to process a single record file
def process_record_file(record_path):
    with open(record_path, 'r') as file:
        instructions = file.readlines()
    
    labeled_entries = []
    
    for instruction in instructions:
        instruction = instruction.strip()  # Clean up whitespace
        
        if instruction:  # Ignore empty lines
            # Tokenize the instruction using the simple tokenizer
            tokens = simple_tokenizer(instruction)
            
            # Generate labels using LangChain
            _, labels = generate_labels_for_instruction(instruction)
            
            # Store in the desired format
            labeled_entries.append({
                "instruction": instruction,
                "tokens": tokens,
                "labels": labels
            })
    
    return labeled_entries

# Function to save labeled data to a JSON file
def save_to_json(record_id, labeled_entries, output_dir="/Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records"):
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, f"{record_id}.json")
    
    with open(output_path, 'w') as json_file:
        json.dump({"record_id": record_id, "entries": labeled_entries}, json_file, indent=4)
    
    print(f"Saved labeled data for {record_id} to {output_path}")

# New function to process all record files in a folder
def process_all_records(records_folder="records"):
    for record_file in os.listdir(records_folder):
        if record_file.endswith('.txt'):  # Process only .txt files
            record_path = os.path.join(records_folder, record_file)
            record_id = os.path.splitext(record_file)[0]
            
            # Process the record file
            labeled_entries = process_record_file(record_path)
            
            # Save to JSON
            save_to_json(record_id, labeled_entries)

# Call the function to process all record files
process_all_records(records_folder="/Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/input")
# Out:
# Saved labeled data for record_016 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_016.json
# Saved labeled data for record_002 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_002.json
# Saved labeled data for record_003 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_003.json
# Saved labeled data for record_017 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_017.json
# Saved labeled data for record_029 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_029.json
# Saved labeled data for record_001 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_001.json
# Saved labeled data for record_015 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_015.json
# Saved labeled data for record_014 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_014.json
# Saved labeled data for record_028 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_028.json
# Saved labeled data for record_004 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_004.json
# Saved labeled data for record_010 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_010.json
# Saved labeled data for record_038 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_038.json
# Saved labeled data for record_039 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_039.json
# Saved labeled data for record_011 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_011.json
# Saved labeled data for record_005 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_005.json
# Saved labeled data for record_013 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_013.json
# Saved labeled data for record_007 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_007.json
# Saved labeled data for record_006 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_006.json
# Saved labeled data for record_012 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_012.json
# Saved labeled data for record_049 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_049.json
# Saved labeled data for record_075 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_075.json
# Saved labeled data for record_061 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_061.json
# Saved labeled data for record_060 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_060.json
# Saved labeled data for record_074 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_074.json
# Saved labeled data for record_048 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_048.json
# Saved labeled data for record_089 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_089.json
# Saved labeled data for record_062 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_062.json
# Saved labeled data for record_076 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_076.json
# Saved labeled data for record_077 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_077.json
# Saved labeled data for record_063 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_063.json
# Saved labeled data for record_088 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_088.json
# Saved labeled data for record_098 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_098.json
# Saved labeled data for record_067 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_067.json
# Saved labeled data for record_073 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_073.json
# Saved labeled data for record_072 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_072.json
# Saved labeled data for record_066 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_066.json
# Saved labeled data for record_099 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_099.json
# Saved labeled data for record_070 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_070.json
# Saved labeled data for record_064 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_064.json
# Saved labeled data for record_058 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_058.json
# Saved labeled data for record_059 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_059.json
# Saved labeled data for record_065 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_065.json
# Saved labeled data for record_071 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_071.json
# Saved labeled data for record_097 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_097.json
# Saved labeled data for record_083 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_083.json
# Saved labeled data for record_068 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_068.json
# Saved labeled data for record_054 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_054.json
# Saved labeled data for record_040 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_040.json
# Saved labeled data for record_041 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_041.json
# Saved labeled data for record_055 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_055.json
# Saved labeled data for record_069 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_069.json
# Saved labeled data for record_082 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_082.json
# Saved labeled data for record_096 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_096.json
# Saved labeled data for record_080 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_080.json
# Saved labeled data for record_094 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_094.json
# Saved labeled data for record_043 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_043.json
# Saved labeled data for record_057 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_057.json
# Saved labeled data for record_056 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_056.json
# Saved labeled data for record_042 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_042.json
# Saved labeled data for record_095 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_095.json
# Saved labeled data for record_081 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_081.json
# Saved labeled data for record_085 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_085.json
# Saved labeled data for record_091 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_091.json
# Saved labeled data for record_046 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_046.json
# Saved labeled data for record_052 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_052.json
# Saved labeled data for record_053 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_053.json
# Saved labeled data for record_047 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_047.json
# Saved labeled data for record_090 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_090.json
# Saved labeled data for record_084 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_084.json
# Saved labeled data for record_092 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_092.json
# Saved labeled data for record_086 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_086.json
# Saved labeled data for record_051 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_051.json
# Saved labeled data for record_045 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_045.json
# Saved labeled data for record_079 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_079.json
# Saved labeled data for record_078 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_078.json
# Saved labeled data for record_044 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_044.json
# Saved labeled data for record_050 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_050.json
# Saved labeled data for record_087 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_087.json
# Saved labeled data for record_093 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_093.json
# Saved labeled data for record_037 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_037.json
# Saved labeled data for record_023 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_023.json
# Saved labeled data for record_022 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_022.json
# Saved labeled data for record_036 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_036.json
# Saved labeled data for record_008 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_008.json
# Saved labeled data for record_020 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_020.json
# Saved labeled data for record_034 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_034.json
# Saved labeled data for record_035 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_035.json
# Saved labeled data for record_021 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_021.json
# Saved labeled data for record_009 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_009.json
# Saved labeled data for record_025 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_025.json
# Saved labeled data for record_031 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_031.json
# Saved labeled data for record_019 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_019.json
# Saved labeled data for record_018 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_018.json
# Saved labeled data for record_030 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_030.json
# Saved labeled data for record_024 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_024.json
# Saved labeled data for record_032 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_032.json
# Saved labeled data for record_026 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_026.json
# Saved labeled data for record_027 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_027.json
# Saved labeled data for record_033 to /Users/remon.m/Desktop/Y4S2/Thesis/Coding/Synth/test_dataset/labeled_records/record_033.json
